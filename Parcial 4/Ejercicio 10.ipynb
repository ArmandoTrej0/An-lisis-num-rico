# %% [markdown]
# #Parra Miranda Emiliano
# #Trejo Acevedo Armando Israel

# %%
import math

# %%
def secante(f, x0, x1, tol, max_iter):
    contador_iteraciones = 0
    while abs(x1 - x0) > tol and contador_iteraciones < max_iter:
        f_x0 = f(x0)
        f_x1 = f(x1)
        if f_x1 - f_x0 == 0:
            raise ValueError("División por cero en el método de la secante.")
        x2 = x1 - f_x1 * (x1 - x0) / (f_x1 - f_x0)  # Nueva aproximación
        x0, x1 = x1, x2
        contador_iteraciones += 1
    return x1

# %% [markdown]
# #a)

# %%
def a(x):
  y= math.exp(x) + 2**(-x) + 2*math.cos(x) - 6
  return y

# %%
y1=secante(a, 1, 2, 10**-5, 1000)
y1
# Out:
# 1.8293836019394727

# %% [markdown]
# #b)

# %%
def b(x):
  y=2*x*math.cos(2*x) - (x-2)**2
  return y

# %%
y21=secante(b, 2, 3, 10**-5, 1000)
y21
# Out:
# 2.3706869176623

# %%
y22=secante(b, 3, 4, 10**-5, 1000)
y22
# Out:
# 3.722112773420417

# %% [markdown]
# #c)

# %%
def c(x):
  y= math.exp(x) - 3*(x**2)
  return y

# %%
y31=secante(c, 0, 1, 10**-5, 1000)
y31
# Out:
# 0.9100075715386231

# %%
y32=secante(c, 3, 5, 10**-5, 1000)
y32
# Out:
# 3.7330790313204982
