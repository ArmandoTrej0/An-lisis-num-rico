# %% [markdown]
# #Parra Miranda Emiliano
# #Trejo Acevedo Armando Israel

# %%
def biseccion(f, a, b, tol, max_iter):
    if f(a) * f(b) >= 0:
        raise ValueError("La función debe cambiar de signo en el intervalo [a, b].")

    contador_iteraciones = 0
    while (b - a) / 2.0 > tol and contador_iteraciones < max_iter:
        c = (a + b) / 2.0  # Punto medio
        if f(c) == 0:
            return c  # Se encontró la raíz exacta
        elif f(a) * f(c) < 0:
            b = c  # La raíz está en el intervalo [a, c]
        else:
            a = c  # La raíz está en el intervalo [c, b]
        contador_iteraciones += 1
    return (a + b) / 2.0

# %%
def f(x):
  y=(x+2) * (x+1)**2 * x * (x-1)**3 * (x-2)
  return y

# %% [markdown]
# #a)

# %%
y1= biseccion(f, -1.5, 2.5, 10**-5, 1000)
y1
#Converge a x=0
# Out:
# 0.0

# %% [markdown]
# #b)

# %%
y2= biseccion(f, -0.5, 2.4, 10**-5, 1000)
y2
#Converge a x=0
# Out:
# 2.8610229492034365e-06

# %% [markdown]
# #c)

# %%
y3= biseccion(f, -0.5, 3, 10**-5, 1000)
y3
#Converge a x=2
# Out:
# 1.9999971389770508

# %% [markdown]
# #d)

# %%
y3= biseccion(f, -3, -0.5, 10**-5, 1000)
y3
#Converge a x=-2
# Out:
# -2.0000057220458984
