# %% [markdown]
# #Parra Miranda Emiliano
# #Trejo Acevedo Armando Israel

# %%
import math

# %%
def biseccion(f, a, b, tol, max_iter):
    if f(a) * f(b) >= 0:
        raise ValueError("La función debe cambiar de signo en el intervalo [a, b].")

    contador_iteraciones = 0
    while (b - a) / 2.0 > tol and contador_iteraciones < max_iter:
        c = (a + b) / 2.0  # Punto medio
        if f(c) == 0:
            return c  # Se encontró la raíz exacta
        elif f(a) * f(c) < 0:
            b = c  # La raíz está en el intervalo [a, c]
        else:
            a = c  # La raíz está en el intervalo [c, b]
        contador_iteraciones += 1
    return (a + b) / 2.0

# %% [markdown]
# # a)

# %%
def a(x):
  y=x - 2**-x
  return y

# %%
y1=biseccion(a, 0, 1, 10**(-5), 10000)
y1
# Out:
# 0.6411819458007812

# %% [markdown]
# #b)

# %%
def b(x):
  y=math.exp(x) - x**2 + 3*x -2
  return y

# %%
y2=biseccion(b, 0, 1, 10**(-5), 10000)
y2
# Out:
# 0.25753021240234375

# %% [markdown]
# #c)

# %%
def c(x):
  y= 2*x*math.cos(2*x) - (x+1)**2
  return y

# %%
y31=biseccion(c, -3, -2, 10**(-5), 10000)
y31
# Out:
# -2.1913070678710938

# %%
y32=biseccion(c, -1, 0, 10**(-5), 10000)
y32
# Out:
# -0.7981643676757812

# %% [markdown]
# #d)

# %%
def d(x):
  y=x*math.cos(x) - 2*(x**2) + 3*x - 1
  return y

# %%
y41=biseccion(d, 0.2, 0.3, 10**(-5), 10000)
y41
# Out:
# 0.29752807617187504

# %%
y42=biseccion(d, 1.2, 1.3, 10**(-5), 10000)
y42
# Out:
# 1.256622314453125
