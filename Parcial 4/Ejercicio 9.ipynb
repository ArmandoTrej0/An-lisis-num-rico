# %% [markdown]
# #Parra Miranda Emiliano
# #Trejo Acevedo Armando Israel

# %%
import math

# %%
def newton(f, df, x0, tol, max_iter):
    contador_iteraciones = 0
    x = x0
    while abs(f(x)) > tol and contador_iteraciones < max_iter:
        x = x - f(x) / df(x)  # Nueva aproximación
        contador_iteraciones += 1
    return x

# %% [markdown]
# #a)

# %%
def a(x):
  y= math.exp(x) + 2**(-x) + 2*math.cos(x) - 6
  return y

# %%
def da(x):
  y= math.exp(x) - math.log(2)/2**x - 2*math.sin(x)
  return y

# %%
y1=newton(a, da, 1, 10**-5, 1000)
y1
# Out:
# 1.829383602512459

# %% [markdown]
# #b)

# %%
def b(x):
  y=2*x*math.cos(2*x) - (x-2)**2
  return y

# %%
def db(x):
  y=2*math.cos(2*x) - 4*x*math.sin(2*x) - 2*x + 4
  return y

# %%
y21=newton(b, db, 2, 10**-5, 1000)
y21
# Out:
# 2.3706870568266094

# %%
y22=newton(b, db, 4, 10**-5, 1000)
y22
# Out:
# 3.7221128228695846

# %% [markdown]
# #c)

# %%
def c(x):
  y= math.exp(x) - 3*(x**2)
  return y

# %%
def dc(x):
  y= math.exp(x) - 6*x
  return y

# %%
y31=newton(c, dc, 1, 10**-5, 1000)
y31
# Out:
# 0.9100075725488881

# %%
y32=newton(c, dc, 3, 10**-5, 1000)
y32
# Out:
# 3.7330790654948975
